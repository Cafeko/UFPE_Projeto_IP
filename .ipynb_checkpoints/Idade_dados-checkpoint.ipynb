# %% [markdown]
# Imports:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %run ./Dados.ipynb
# %run ./Funcoes.ipynb

# %% [markdown]
# Funções:

# %%
def ProcessamentoIdade(df, ano):
    copia_df = df.copy()
    try:
        copia_df = ParteDataFrame(copia_df, ["ANO_NASCIMENTO", "SEXO", "CURSO"])
        copia_df["IDADE"] = CalculaIdades(copia_df["ANO_NASCIMENTO"], ano)
        copia_df = RemoveColunas(copia_df, "ANO_NASCIMENTO")
        copia_df["AREA"] = GruposDicio(copia_df["CURSO"], cursos_areas)
        copia_df = pd.concat([ColLoc(copia_df, "SEXO", "F"), ColLoc(copia_df, "SEXO", "M")])
        return copia_df
    except:
        print("Erro")
        return df

# %%
def IdadePlot(df, x, hue, palette, ax, titulo="", titulo_tamanho=15, despine=False):
    grafico = sns.kdeplot(data=df, x=x, hue=hue, palette=CoresPalette(df[hue], palette), ax=ax, fill=True).set_title(titulo, fontsize=titulo_tamanho, y=1.05)
    
    ax.legend(title='Sexo', loc='upper right', labels=['Masculino', 'Feminino'])
    
    if despine:
        sns.despine(top=True , right=True, left=False, bottom=False)
    
    return grafico

# %% [markdown]
# Processamento dos dados:

# %%
# 2021
df_idades21 = ProcessamentoIdade(df21, 2021)

# 2022
df_idades22 = ProcessamentoIdade(df22, 2022)

# %% [markdown]
# # Gráficos de Idades:

# %% [markdown]
# # 2021

# %%
idades_geral21, pos1 = plt.subplots(nrows = 1, ncols=1, figsize=(10, 5))

idades_geral21 = IdadePlot(df_idades21, "IDADE", "SEXO", sexo_palette, pos1, "Idades geral 2021",  despine=True)

plt.show(idades_geral21)

# %%
idades_area21, pos2 = plt.subplots(nrows = 1, ncols=3, figsize=(20, 5))

idades_area21.suptitle("Idades por area 2021", fontsize=20, y=1.05)

IdadePlot(ColLoc(df_idades21, "AREA", "HUMANAS"), "IDADE", "SEXO", sexo_palette, pos2[0], "Humanas")
IdadePlot(ColLoc(df_idades21, "AREA", "EXATAS"), "IDADE", "SEXO", sexo_palette, pos2[1], "Exatas")
IdadePlot(ColLoc(df_idades21, "AREA", "SAUDE"), "IDADE", "SEXO", sexo_palette, pos2[2], "Saude")

plt.show(idades_area21)

# %% [markdown]
# # 2022

# %%
idades_geral22, pos3 = plt.subplots(figsize=(10, 5))

idades_geral22 = IdadePlot(df_idades22, "IDADE", "SEXO", sexo_palette, pos3, "Idades geral 2022", despine=True)

plt.show(idades_geral22)

# %%
idades_area22, pos4 = plt.subplots(nrows = 1, ncols=3, figsize=(20, 5))

plt.suptitle("Idades por area 2022", fontsize=20, y=1.05)

idades_area22 = IdadePlot(ColLoc(df_idades22, "AREA", "HUMANAS"), "IDADE", "SEXO", sexo_palette, pos4[0], "Humanas")
idades_area22 = IdadePlot(ColLoc(df_idades22, "AREA", "EXATAS"), "IDADE", "SEXO", sexo_palette, pos4[1], "Exatas")
idades_area22 = IdadePlot(ColLoc(df_idades22, "AREA", "SAUDE"), "IDADE", "SEXO", sexo_palette, pos4[2], "Saude")

plt.show(idades_area22)
