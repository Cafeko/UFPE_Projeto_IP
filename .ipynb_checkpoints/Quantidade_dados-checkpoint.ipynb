# %% [markdown]
# Imports:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %run ./Dados.ipynb
# %run ./Funcoes.ipynb

# %% [markdown]
# Funções:

# %%
def ProcessamentoQuantidade(df):
    copia_df = df.copy()
    try:
        copia_df = ParteDataFrame(copia_df, ["ANO_INGRESSO", "CURSO", "SEXO"])
        copia_df["AREA"] = GruposDicio(copia_df["CURSO"], cursos_areas)
        copia_df = RemoveColunas(copia_df, "CURSO")
        copia_df = pd.concat([ColLoc(copia_df, "SEXO", "F"), ColLoc(copia_df, "SEXO", "M")])
        return copia_df
    except:
        print("Erro")
        return df

# %%
def QuantidadePlot(df, x, hue, palette, ax, titulo="", titulo_tamanho=15, despine=False):
    grafico = sns.histplot(data=df, x=x, hue=hue, palette=CoresPalette(df[hue], palette), ax=ax).set_title(titulo, fontsize=titulo_tamanho, y=1.05)
    
    ax.legend(title='Sexo', loc='upper right', labels=['Masculino', 'Feminino'])
    
    if despine:
        sns.despine(top=True , right=True, left=False, bottom=False)
    
    return grafico

# %% [markdown]
# Processamento dos dados:

# %%
# Geral
df_quant_geral = pd.concat([df21,df22])
df_quant_geral = ProcessamentoQuantidade(df_quant_geral)

# 2021
df_quant21 = ColLoc(df_quant_geral, "ANO_INGRESSO", 2021)

# 2022
df_quant22 = ColLoc(df_quant_geral, "ANO_INGRESSO", 2022)

# %% [markdown]
# # Gráficos de Quantidades:

# %% [markdown]
# # 2021

# %%
quantidade_geral21, pos1 = plt.subplots(nrows = 1, ncols=1, figsize=(7, 5))

QuantidadePlot(df_quant21, "SEXO", "SEXO", sexo_palette, pos1, "Quantidade geral 2021")

plt.show(quantidade_geral21)

# %%
quantidade_area21, pos2 = plt.subplots(nrows = 1, ncols=3, figsize=(20, 5))

quantidade_area21.suptitle("Quantidade por area 2021", fontsize=20, y=1.05)

QuantidadePlot(ColLoc(df_quant21, "AREA", "HUMANAS"), "SEXO", "SEXO", sexo_palette, pos2[0], "Humanas")
QuantidadePlot(ColLoc(df_quant21, "AREA", "EXATAS"), "SEXO", "SEXO", sexo_palette, pos2[1], "Exatas")
QuantidadePlot(ColLoc(df_quant21, "AREA", "SAUDE"), "SEXO", "SEXO", sexo_palette, pos2[2], "Saude")

plt.show(quantidade_area21)

# %% [markdown]
# # 2022

# %%
quantidade_geral22, pos3 = plt.subplots(nrows = 1, ncols=1, figsize=(7, 5))

quantidade_geral22 = QuantidadePlot(df_quant22, "SEXO", "SEXO", sexo_palette, pos3, "Quantidade geral 2022")

plt.show(quantidade_geral22)

# %%
quantidade_area22, pos4 = plt.subplots(nrows = 1, ncols=3, figsize=(20, 5))

quantidade_area22.suptitle("Quantidade por area 2022", fontsize=20, y=1.05)

QuantidadePlot(ColLoc(df_quant22, "AREA", "HUMANAS"), "SEXO", "SEXO", sexo_palette, pos4[0], "Humanas")
QuantidadePlot(ColLoc(df_quant22, "AREA", "EXATAS"), "SEXO", "SEXO", sexo_palette, pos4[1], "Exatas")
QuantidadePlot(ColLoc(df_quant22, "AREA", "SAUDE"), "SEXO", "SEXO", sexo_palette, pos4[2], "Saude")

plt.show(quantidade_area22)
