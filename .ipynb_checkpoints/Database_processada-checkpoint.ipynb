# %%
import pandas as pd #Utilizado para manipular os dados

#.read_csv(local ou link do csv) é um comando que abre o dataset em formato de dataframe (ou tabelinha)
pre_df_22 = pd.read_csv('https://dados.ufpe.br/dataset/cba99924-ad97-45f6-9d1c-f4fb7a940c6f/resource/3ec70513-eca6-453d-95d1-fde1f1972a11/download/discentes-2022-ufpe.csv') 
pre_df_21 = pd.read_csv('https://dados.ufpe.br/dataset/cba99924-ad97-45f6-9d1c-f4fb7a940c6f/resource/3b4468e4-1f72-49c1-bbf3-5d71216b85e5/download/discentes-ingressos-cursos-graduacao-2021-ufpe.csv')

# %%
# %run ./Funcoes.ipynb

# %%
pre_df_22
# Out:
#       CD_DISCENTE  ANO_INGRESSO  SEMESTRE_INGRESSO TIPO_INGRESSO   CAMPUS  \
# 0          359082          2022                  1          SISU  AGRESTE
# 1          358668          2022                  1          SISU  AGRESTE
# 2          357112          2022                  1          SISU  AGRESTE
# 3          357368          2022                  1          SISU  AGRESTE
# 4          354685          2022                  1          SISU  AGRESTE
# ...           ...           ...                ...           ...      ...
# 4840       337953          2022                  1          SISU  VITORIA
# 4841       358950          2022                  1          SISU  VITORIA
# 4842       354165          2022                  1          SISU  VITORIA
# 4843       358994          2022                  1          SISU  VITORIA
# 4844       353842          2022                  1          SISU  VITORIA
#
#       COD_CURSO                 CURSO            NATURALIDADE UF_NATURALIDADE  \
# ...

# %%
pre_df_21
# Out:
#       CD_DISCENTE  ANO_INGRESSO  SEMESTRE_INGRESSO TIPO_INGRESSO   CAMPUS  \
# 0          350507          2021                  1          SISU  AGRESTE
# 1          349810          2021                  1          SISU  AGRESTE
# 2          349323          2021                  1          SISU  AGRESTE
# 3          349733          2021                  1          SISU  AGRESTE
# 4          349062          2021                  1          SISU  AGRESTE
# ...           ...           ...                ...           ...      ...
# 4630       348541          2021                  1          SISU  VITORIA
# 4631       350632          2021                  1          SISU  VITORIA
# 4632       350459          2021                  1          SISU  VITORIA
# 4633       349254          2021                  1          SISU  VITORIA
# 4634       254822          2021                  1          SISU  VITORIA
#
#       COD_CURSO                 CURSO            NATURALIDADE UF_NATURALIDADE  \
# ...

# %%
remover = ['CD_DISCENTE', 'ANO_INGRESSO', 'SEMESTRE_INGRESSO', 'TIPO_INGRESSO', 'CURSO', 'NATURALIDADE', 
                          "SEXO", 'PAIS_NATURALIDADE','UF_NATURALIDADE', 'UF_ENDERECO', 'COTA', 
                          "ESCOLARIDADE_PAI", "ESCOLARIDADE_MAE",]
ordem = ["COD_CURSO","ANO_NASCIMENTO", "IDADE","DEFICIENCIA","HOMEM","MULHER","CAMPUS_num","BAIRRO_ENDERECO_num",
                         "CIDADE_ENDERECO_num","TIPO_COTA_num","FUNDAMENTAL_PAI","ENSINO MEDIO_PAI","ENSINO SUPERIOR_PAI",
                         "FUNDAMENTAL_MAE","ENSINO MEDIO_MAE","ENSINO SUPERIOR_MAE"]

# %%
df_22 = Processamento(pre_df_22, 2022, colunas_remover = remover, colunas_ordem = ordem)
df_21 = Processamento(pre_df_21, 2021, colunas_remover = remover, colunas_ordem = ordem)

# %%
df_22
# Out:
#       COD_CURSO  ANO_NASCIMENTO  IDADE  DEFICIENCIA  HOMEM  MULHER  \
# 0          1000            2001     21            0      1       0
# 1          1000            2003     19            0      1       0
# 2          1000            2004     18            0      1       0
# 3          1000            2002     20            0      1       0
# 4          1000            2004     18            0      1       0
# ...         ...             ...    ...          ...    ...     ...
# 4840        348            1969     53            0      0       1
# 4841        348            1999     23            0      0       1
# 4842        348            2002     20            0      0       1
# 4843        348            2005     17            0      0       1
# 4844        348            1999     23            0      1       0
#
#       CAMPUS_num  BAIRRO_ENDERECO_num  CIDADE_ENDERECO_num  TIPO_COTA_num  \
# 0              0                   90                    5              7
# ...

# %%
df_21
# Out:
#       COD_CURSO  ANO_NASCIMENTO  IDADE  DEFICIENCIA  HOMEM  MULHER  \
# 0          1000            2002     19            0      0       1
# 1          1000            2002     19            0      1       0
# 2          1000            2000     21            0      1       0
# 3          1000            2000     21            0      0       1
# 4          1000            2002     19            0      0       1
# ...         ...             ...    ...          ...    ...     ...
# 4630        348            2001     20            0      0       1
# 4631        348            2002     19            0      0       1
# 4632        348            2003     18            0      0       1
# 4633        348            2003     18            0      0       1
# 4634        348            1984     37            0      1       0
#
#       CAMPUS_num  BAIRRO_ENDERECO_num  CIDADE_ENDERECO_num  TIPO_COTA_num  \
# 0              0                  116                   82              0
# ...
